# %% [markdown]
# Movie Recommendation System
#
# 1. Project Overview
#
# 2. Problem Statement
#
# 3. Dataset Description
#
# 4. Understanding Recommendation Systems
#
# 5. Data Loading
#
# 6. Data Quality Assessment
#
# 7. Exploratory Data Analysis
#
# 8. Data Preprocessing
#
# 9. Feature Engineering
#
# 10. Recommendation Strategy
#
# 11. Building the Similarity Matrix
#
# 12. Recommendation Pipeline
#
# 13. Testing Recommendations
#
# 14. Saving Model Artifacts
#
# 15. Limitations
#
# 16. Future Improvements

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')


import nltk 
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df = pd.read_csv(r"D:\Robotics\Machine Learning Projects\Movie Recommendation System\data\movies_metadata.csv")

# %%
df1 = pd.read_csv(r"D:\Robotics\Machine Learning Projects\Movie Recommendation System\data\movies_metadata.csv")

# %%
df1.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %% [markdown]
# ## EDA

# %%
df.shape
# Out:
# (45466, 24)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  str
#  1   belongs_to_collection  4494 non-null   str
#  2   budget                 45466 non-null  str
#  3   genres                 45466 non-null  str
#  4   homepage               7782 non-null   str
#  5   id                     45466 non-null  str
#  6   imdb_id                45449 non-null  str
#  7   original_language      45455 non-null  str
#  8   original_title         45466 non-null  str
#  9   overview               44512 non-null  str
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  str
#  12  production_companies   45463 non-null  str
#  13  production_countries   45463 non-null  str
#  14  release_date           45379 non-null  str
# ...

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='str')

# %% [markdown]
# ## 🥇 Essential (Must-Have Features)
# These 6 columns carry 80–90% of the predictive signal for your recommender.
#
# 1. **genres**
#
# Why: The single strongest categorical signal. User preferences heavily anchor on genre (e.g., Action vs. Romance).
#
# 2. **overview**
#
# Why: Plot summaries contain rich textual information (themes, tropes, settings) ideal for NLP similarity modeling.
#
# 3. **title**
#
# Why: Required as the human-readable output label for your recommendations.
#
# 4. **id (or imdb_id)**
#
# Why: Essential system primary key for indexing, deduplication, and joining with other datasets.
#
# 5. **vote_count**
#
# Why: Crucial quality control. Filters out obscure films with 1 artificial "10/10" rating before calculating scores.
#
# 6. **vote_average**
#
# Why: Core metric for quality weighting (e.g., combining with vote_count using IMDb’s weighted rating formula).

# %%
df.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
df1 = df1.drop_duplicates().reset_index(drop=True)

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df[['title','overview','genres','tagline','vote_average','popularity',]]

# %%
df1 = df1[['title','overview','genres','tagline','vote_average','popularity',]]

# %%
df1.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                      genres  \
# 0   Animation Comedy Family
# 1  Adventure Fantasy Family
# 2            Romance Comedy
# 3      Comedy Drama Romance
# 4                    Comedy
#
#                                              tagline  vote_average popularity
# 0                                                              7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %%
df
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45448                       Subdue
# 45449          Century of Birthing
# 45450                     Betrayal
# 45451             Satan Triumphant
# 45452                     Queerama
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 45448        Rising and falling between a man and woman.
# 45449  An artist struggles to finish his work while a...
# ...

# %%
df.isnull().sum()
# Out:
# title               6
# overview          954
# genres              0
# tagline         25045
# vote_average        6
# popularity          5
# dtype: int64

# %% [markdown]
# ## Data cleaning

# %%
# Removing null rows with respect to title
df = df.dropna(subset=['title'])

# %%
df1 = df1.dropna(subset=['title'])

# %%
df1.isnull().sum()
# Out:
# title           0
# overview        0
# genres          0
# tagline         0
# vote_average    0
# popularity      0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# title           0
# overview        0
# genres          0
# tagline         0
# vote_average    0
# popularity      0
# tags            0
# dtype: int64

# %%
df1['overview']= df['overview'].fillna('')

# %%
# Replacing null values from overview with empty strings
df['overview']=df['overview'].fillna('')

# %%
df.iloc[0]['genres']
# Out:
# 'Animation Comedy Family'

# %%
df.iloc[0]['genres']
# Out:
# 'Animation Comedy Family'

# %%
import ast
df['genres'] = df['genres'].apply(lambda x :" ".join([i['name'] for i in ast.literal_eval(x)]))

# %%
df['genres'] = df['genres'].apply(lambda x : " ".join([i['name'] for i in ast.literal_eval(x)]))
# Out:
# Traceback (most recent call last):
#
#   File d:\Robotics\Machine Learning Projects\Movie Recommendation System\movie_env\Lib\site-packages\IPython\core\interactiveshell.py:3748 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[59], line 1
#     df['genres'] = df['genres'].apply(lambda x : " ".join([i['name'] for i in ast.literal_eval(x)]))
#
#   File d:\Robotics\Machine Learning Projects\Movie Recommendation System\movie_env\Lib\site-packages\pandas\core\series.py:5084 in apply
#     ).apply()
#
#   File d:\Robotics\Machine Learning Projects\Movie Recommendation System\movie_env\Lib\site-packages\pandas\core\apply.py:1520 in apply
#     return self.apply_standard()
#
#   File d:\Robotics\Machine Learning Projects\Movie Recommendation System\movie_env\Lib\site-packages\pandas\core\apply.py:1578 in apply_standard
#     mapped = obj._map_values(mapper=curried)
#
# ...

# %%
df1.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                      genres  \
# 0   Animation Comedy Family
# 1  Adventure Fantasy Family
# 2            Romance Comedy
# 3      Comedy Drama Romance
# 4                    Comedy
#
#                                              tagline  vote_average popularity
# 0                                                              7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                      genres  \
# 0   Animation Comedy Family
# 1  Adventure Fantasy Family
# 2            Romance Comedy
# 3      Comedy Drama Romance
# 4                    Comedy
#
#                                              tagline  vote_average popularity
# 0                                                NaN           7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %%
df['tagline']= df['tagline'].fillna('')

# %%
df1['tagline']=df1['tagline'].fillna('')

# %%
df['tags'] = df['overview']+ " " + df['genres'] +" "+ df['tagline']

# %%
df1['tags']=df['overview']+" "+ df['genres']+" "+df['tagline']

# %%
df1['tags'][1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures. Adventure Fantasy Family Roll the dice and unleash the excitement!"

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                      genres  \
# 0   Animation Comedy Family
# 1  Adventure Fantasy Family
# 2            Romance Comedy
# 3      Comedy Drama Romance
# 4                    Comedy
#
#                                              tagline  vote_average popularity  \
# 0                                                              7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %%
df['tags'][1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures. Adventure Fantasy Family Roll the dice and unleash the excitement!"

# %%
df1['tags'][1]
# Out:
# ''

# %% [markdown]
# ## Text Processing

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
def preprocess_text(text):
  #lowercase
  text = str(text).lower()
  #removed the punctuations
  text = re.sub(r'[^a-zA-Z\s]', '', text)

  words = text.split()
  #remove stopwords
  words = [word for word in words if word not in stop_words]

  #lemmatize
  words = [lemmatizer.lemmatize(word) for word in words]

  return " ".join(words)

# %%
df1['tags'] =df['tags'].apply(preprocess_text)

# %%
df['tags'] = df['tags'].apply(preprocess_text)

# %%
df['tags'][0]
# Out:
# ''

# %%
df1['tags'][1]
# Out:
# ''

# %%
df = df.reset_index(drop=True)

# %%
indices = pd.Series(df.index,index = df['title']).drop_duplicates()
indices
# Out:
# title
# Toy Story                          0
# Jumanji                            1
# Grumpier Old Men                   2
# Waiting to Exhale                  3
# Father of the Bride Part II        4
#                                ...
# Subdue                         45442
# Century of Birthing            45443
# Betrayal                       45444
# Satan Triumphant               45445
# Queerama                       45446
# Length: 45447, dtype: int64

# %%
df['tags'][1]
# Out:
# ''
