# %% [markdown]
# # **Evolution of Recommendation Systems**
#
# Think of recommendation system evolving through generations
#
# Generation 1
# Popularity-Based
#
# ↓
#
# Generation 2
# Content-Based Filtering
#
# ↓
#
# Generation 3
# Collaborative Filtering
#
# ↓
#
# Generation 4
# Matrix Factorization
#
# ↓
#
# Generation 5
# Deep Learning Recommenders
#
# ↓
#
# Generation 6
# Large-Scale Multi-Stage Recommendation Systems
# (Current Netflix, Amazon, YouTube, TikTok)
