# %% [markdown]
# We are here to learn concepts involved in building **Recommendation system** using machine learnng .
#
# Many tutorial teach :
# TF-IDF -> Cosine Similarity -> Recommend movies
#
# We should be able to answer the interview questions like :
# - Why cosine similarity instead of Euclidean distanace ?
# - Why TF-IDF ?
# - What are vectire in this context ?
# - Why do we normalize ?
# - Why is cosine is bound between -1 to 1 ?
# - What are the limitations of content-based recommenders?
#
# We will learn this like a ML engineer rather than a tutorial follower

# %% [markdown]
# ## Why Recommendation Systems?
#
# Recommendation Systems are essential for several reasons:
#
# 1. Recommendation Systems offer personalized suggestions based on user preferences and user ratings, ensuring that they discover content and products that are relevant and interesting to them.
#
# 2. By providing tailored recommendations, users are more likely to engage with the platform, increasing user satisfaction and retention.
# 3. E-commerce platforms like Amazon use recommendation engines to promote products, leading to higher sales and revenue as users discover and purchase items they might not have considered.
# 4. In today’s digital landscape, recommendation systems help users navigate the overwhelming amount of available content, making it easier to find a particular movie or series they seek or in any language they want, like English or Korean.
# 5. Recommendation algorithms expose users to new and diverse content, expanding their horizons and introducing them to items they might have overlooked.
# 6. Relying on past behavior and preferences, recommendation systems help users make informed decisions about complex and subjective choices such as movies, music, or books

# %% [markdown]
# ## **RoadMap we will follow**
#
# Instead of jumping straight to cosine similarity , we'll build the concepts from first principles.
#
# **Phase 1- Recommendation System Fundamentals**
#
# Let's start with the big picture .
#
# Topics :
# - What is the recommendation system ?
# - Why recommendation is an ML problem
# - Different recommendation approaches
#    1. Pupularity based
#    2. Content based
#    3. Collaburative filtering
#    4. Hybrid Systems
# - Real-world examples
#    - Netflix
#    - Amazon
#    - Spotify
#    - YouTube
#
# Our goal : By the end , we wil know why different recommendation system exist.
#
# **Phase2 : Representing Movies as Mathematics**
# This is where we willl learn what is not included in generic tutorials
#
# we will be to answer :
#  | How does a computer understand a movie ?
#
# A Movie like
# Interstellar
#
# Genres:
# Adventure
# Sci-Fi
#
# Overview:
# A team of explorers travels through a wormhole...
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Interstellar
#
# Genres:
# Adventure
# Sci-Fi
#
# Overview:
# A team of explorers travels through a wormhole...
# </div>
#
# - becomes
# [0.18, 0.04, 0.91, 0.27, ...]
#
# - Question we'll answer
#
#  - What is a feature ?
#  - What is a feature vector ?
#  - What is vector space?
#  - Sparse vectors
#  - Dense vectors
#  - High-dimensional data
# ---
# **Phase 3 – NLP Behind Movie Recommendations**
#
# Most movie recommenders rely heavily on text.
#
# We'll study:
#
# - Tokenization
# - Stop words
# - Lemmatization
# - Stemming
# - Bag of Words
# - Count Vectorizer
# - TF
# - IDF
# - TF-IDF
#
# You'll understand exactly why
#
# "the"
#
# should not influence recommendations.
#
#
# ---
#
# **Phase 4 – Cosine Similarity (Deep Dive)**
#
# This deserves its own chapter.
#
# We'll cover:
#
# - Why Euclidean distance fails
# - Angles between vectors
# - Dot product
# - Vector magnitude
# - Unit vectors
# - Cosine similarity formula
# - Geometric intuition
# - Numerical example by hand
# - Python implementation from scratch
# - sklearn implementation
# - Complexity analysis
#
# Most importantly:
#
# You'll understand why cosine similarity works.
#
# ---
# **Phase 5 – Building the Recommendation Engine**
#
# Only now will we start coding.
#
# Pipeline:
# Movies
#
# ↓
#
# Cleaning
#
# ↓
#
# Feature Engineering
#
# ↓
#
# Combine Metadata
#
# ↓
#
# Vectorization
#
# ↓
#
# Cosine Similarity Matrix
#
# ↓
#
# Top K Recommendations
#
# ----
# **Phase 6 – Improving the Recommendation System**
#
# Real recommendation systems don't stop at cosine similarity.
#
# We'll study:
#
# - Genre weighting
# - Keyword weighting
# - Cast importance
# - Director importance
# - Popularity weighting
# - Runtime filtering
# - Year filtering
